# %% [markdown]
# <a href="https://colab.research.google.com/github/HongWonSeok/STUDY/blob/main/%EB%AA%A8%EB%91%90%EB%A5%BC_%EC%9C%84%ED%95%9C_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%8B%9C%EC%A6%8C2_LAB_10_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ImageFolder**

# %% [markdown]
# **사진을 이용하여 딥러닝 모델 학습해보기**
# - 데이터 셋 준비하기
# - torchvision.datasets.ImageFolder으로 불러오기
# - transforms 적용하여 저장하기 origin_data -> train_data
# - 사진을 분류하는 딥러닝 모델 학습
#   - 사진을 이요하여 dataset을 만드는 법
#   - 배운내용을 이용해서 학습하기
#   - 모델을 저장하고 다시 불러오는 법

# %% [markdown]
# 데이터 셋 준비하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **코드는 사진으로!**

# %% [markdown]
# **Neural Network 만들기**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Layer1
#  - rgb 3채널을 받아서 출력은 6채널로 하게하고, kernel_size는 5(5,5)로하고 stride =1, padding은 주지 않았다.
#  - MaxPool 2,2로 진행을하였다.
#
# Layer2
#  - 1에서 출력이 6채널이였으므로 2의 입력은 6채널로, 출력은 16채널로 나가게 하였다.
#
# Layer3
#  - Layer 1,2를 진행하게되면 그림의 3 x 64 x 128이 [16,13,29]로 바뀌게 된다.
#  - 그래서 6032를 120으로 나오고.
#  - 그리고 120을 2로 나오게하는 fully connectted 2개를 거쳐서 cross Entropy를 계산하는 형태이다.
#
#
# **코드는 사진으로!**
